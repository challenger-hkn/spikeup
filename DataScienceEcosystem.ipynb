# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## **Data Science Tools and Ecosystem**

# %% [markdown]
# **In this notebook, Data Science Tools and Ecosystem are summarized** <br>
# Introduction of assignment Topic:
#
# You will be provided with an empty Jupyterlite notebook which you will launch in the course, to complete this assignment. <br>
# You will need to include a combination of markdown and code cells. <br>
# You will likely need to use the Markdown cheat sheet to help you determine the appropriate syntax for your markdown.

# %% [markdown]
# #### **list of data scientist language** <br>Some of the commonly used libraries used by Data Scientists include:
# 1. Python
# 2. SQL
# 3. R
# 4. C++
# 5. Scala
# 6. JS
# 7. Julia

# %% [markdown]
# #### **list of data scientist library** <br>
# - Pandas
# - Seaborn
# - Tensorflow
# - Nltk
# - Matplotlib
# - Numpy
# - Keras
# - ggplot
# - Pytorch

# %% [markdown]
# #### **list of data scientist tools** <br>
# - IBM Watson
# - Apachi Spark
# - Git
# - Github
# - IBM SPSS modeller
# - SPSS statistic
# - RStudio
# - Jupyter

# %%
#### **list of aritmethic expressions** <br> This a simple arithmetic expression to mutiply then add integers
# - 3+5, 4-2 , 10/3 , 10//3, 5*2, 5**2, 10%2, 
x=3**3-13
x
# Out:
# 14

# %%
# Create a code cell to multiply and add numbers.
3*5 
3+1
# Out:
# 4

# %%
## Create a code cell to convert minutes to hours
a=80   # a=minutes
b=60 
c=a/b
f" {a} minutes: {c:.2f} hours"
# Out:
# ' 80 minutes: 1.33 hours'

# %% [markdown]
# Insert a markdown cell to list Objectives
# list of language
# - Python
# - SQL

# %% [markdown]
# Create a markdown cell to indicate the Author's name
# ## Author: Hakan
